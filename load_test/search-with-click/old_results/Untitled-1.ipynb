# %%
import pandas as pd

pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', 100)

# %%
data=pd.read_csv('../results_1000/results.csv')

# %%
data["threadName"]=data["threadName"].apply(lambda x: x[15:])

# %%
data.drop(["responseCode","responseMessage","dataType","success","failureMessage","bytes","sentBytes","grpThreads","allThreads","Latency","IdleTime","Connect"],axis=1,inplace=True)

# %%
#data["URL"]

th=data[data["threadName"]=="5"].sort_values(by="timeStamp")

# %%
th
# Out:
#            timeStamp  elapsed               label threadName  \
# 656    1719447284138      838   GET search/:title          5
# 1464   1719447286178        3  GET title/:titleId          5
# 2939   1719447297046        4   GET search/:title          5
# 4942   1719447307575        4   GET search/:title          5
# 4943   1719447307586        3   GET search/:title          5
# 4944   1719447307596        3   GET search/:title          5
# 4945   1719447307602        3  GET title/:titleId          5
# 6914   1719447317607        4   GET search/:title          5
# 6915   1719447317613        3  GET title/:titleId          5
# 8905   1719447327620        3   GET search/:title          5
# 8906   1719447327625        4  GET title/:titleId          5
# 10901  1719447337630        4   GET search/:title          5
# 10902  1719447337636        3  GET title/:titleId          5
# 12910  1719447347642        4   GET search/:title          5
# 12911  1719447347648        3  GET title/:titleId          5
# 14916  1719447357654        3   GET search/:title          5
# 16885  1719447367660        1   GET search/:title          5
# 16886  1719447367664        4  GET title/:titleId          5
# 18891  1719447377671        3   GET search/:title          5
# 18892  1719447377677        3   GET search/:title          5
# 18893  1719447377681        3  GET title/:titleId          5
#
#                                                                                                        URL
# 656                           http://192.168.1.25:3000/search/%D0%B2%20%D1%81%D0%B2%D1%8F%D1%82.../?page=1
# 1464                                                             http://192.168.1.25:3000/title/tt2294677/
# 2939   http://192.168.1.25:3000/search/ley%20y%20orden%3A%20unidad%20de%20v%C3%ADctimas%20especiales/?p...
# 4942                                               http://192.168.1.25:3000/search/dan%20odlocitve/?page=1
# 4943                                               http://192.168.1.25:3000/search/dan%20odlocitve/?page=2
# 4944                                               http://192.168.1.25:3000/search/dan%20odlocitve/?page=2
# 4945                                                             http://192.168.1.25:3000/title/tt2223990/
# 6914                                                  http://192.168.1.25:3000/search/kara%20delik/?page=1
# 6915                                                             http://192.168.1.25:3000/title/tt0078869/
# 8905                                       http://192.168.1.25:3000/search/contacto%20en%20francia/?page=1
# 8906                                                             http://192.168.1.25:3000/title/tt0067116/
# 10901                                                      http://192.168.1.25:3000/search/majster/?page=1
# 10902                                                            http://192.168.1.25:3000/title/tt1560747/
# 12910                                                 http://192.168.1.25:3000/search/interstellar/?page=1
# 12911                                                            http://192.168.1.25:3000/title/tt0816692/
# 14916                                   http://192.168.1.25:3000/search/%C5%BEivljenje%20je%20lepo/?page=1
# 16885                           http://192.168.1.25:3000/search/my%20dear%20f%2A%2A%2Aing%20prince/?page=1
# 16886                                                           http://192.168.1.25:3000/title/tt10172266/
# 18891                                                http://192.168.1.25:3000/search/deep%20impact/?page=1
# 18892                                                http://192.168.1.25:3000/search/deep%20impact/?page=2
# 18893                                                            http://192.168.1.25:3000/title/tt0120647/

# %%
#th[th["URL"].str.contains("./?page=1", regex=True)]

def cycle(x:pd.Series):
    
    if x["URL"].str.contains("./?page=1", regex=True):
        
        x["timestamp"]+x["elapsed"]
        
th.apply(lambda x: x["URL"] if x["URL"].find("page=1")!=-1 else None, axis=1)
# Out:
# 656                             http://192.168.1.25:3000/search/%D0%B2%20%D1%81%D0%B2%D1%8F%D1%82.../?page=1
# 1464                                                                                                    None
# 2939     http://192.168.1.25:3000/search/ley%20y%20orden%3A%20unidad%20de%20v%C3%ADctimas%20especiales/?p...
# 4942                                                 http://192.168.1.25:3000/search/dan%20odlocitve/?page=1
# 4943                                                                                                    None
# 4944                                                                                                    None
# 4945                                                                                                    None
# 6914                                                    http://192.168.1.25:3000/search/kara%20delik/?page=1
# 6915                                                                                                    None
# 8905                                         http://192.168.1.25:3000/search/contacto%20en%20francia/?page=1
# 8906                                                                                                    None
# 10901                                                        http://192.168.1.25:3000/search/majster/?page=1
# 10902                                                                                                   None
# 12910                                                   http://192.168.1.25:3000/search/interstellar/?page=1
# 12911                                                                                                   None
# 14916                                     http://192.168.1.25:3000/search/%C5%BEivljenje%20je%20lepo/?page=1
# 16885                             http://192.168.1.25:3000/search/my%20dear%20f%2A%2A%2Aing%20prince/?page=1
# 16886                                                                                                   None
# 18891                                                  http://192.168.1.25:3000/search/deep%20impact/?page=1
# 18892                                                                                                   None
# 18893                                                                                                   None
# dtype: object

# %%
th[th["URL"].str.contains(".?page=1", regex=True)]
# Out:
#            timeStamp  elapsed              label threadName  \
# 656    1719447284138      838  GET search/:title          5
# 2939   1719447297046        4  GET search/:title          5
# 4942   1719447307575        4  GET search/:title          5
# 6914   1719447317607        4  GET search/:title          5
# 8905   1719447327620        3  GET search/:title          5
# 10901  1719447337630        4  GET search/:title          5
# 12910  1719447347642        4  GET search/:title          5
# 14916  1719447357654        3  GET search/:title          5
# 16885  1719447367660        1  GET search/:title          5
# 18891  1719447377671        3  GET search/:title          5
#
#                                                                                                        URL
# 656                           http://192.168.1.25:3000/search/%D0%B2%20%D1%81%D0%B2%D1%8F%D1%82.../?page=1
# 2939   http://192.168.1.25:3000/search/ley%20y%20orden%3A%20unidad%20de%20v%C3%ADctimas%20especiales/?p...
# 4942                                               http://192.168.1.25:3000/search/dan%20odlocitve/?page=1
# 6914                                                  http://192.168.1.25:3000/search/kara%20delik/?page=1
# 8905                                       http://192.168.1.25:3000/search/contacto%20en%20francia/?page=1
# 10901                                                      http://192.168.1.25:3000/search/majster/?page=1
# 12910                                                 http://192.168.1.25:3000/search/interstellar/?page=1
# 14916                                   http://192.168.1.25:3000/search/%C5%BEivljenje%20je%20lepo/?page=1
# 16885                           http://192.168.1.25:3000/search/my%20dear%20f%2A%2A%2Aing%20prince/?page=1
# 18891                                                http://192.168.1.25:3000/search/deep%20impact/?page=1

# %%
#{k:group.sort_values("timeStamp").drop("threadName", axis=1) for k, group in data.groupby("threadName")}
